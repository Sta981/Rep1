# %% [markdown]
# ## _Data Creation_

# %%
import pandas as pd

# %%
df = pd.read_csv("Market_Sales.csv")
df
# Out:
#      sale_id branch      city customer_type  gender  product_name  \
# 0        1.0      A  New York        Member    Male       Shampoo
# 1        NaN    NaN       NaN           NaN     NaN           NaN
# 2        3.0      A  New York        Member  Female         Apple
# 3        4.0      A   Chicago        Normal    Male     Detergent
# 4        NaN    NaN       NaN           NaN     NaN           NaN
# ..       ...    ...       ...           ...     ...           ...
# 995      NaN    NaN       NaN           NaN     NaN           NaN
# 996      NaN    NaN       NaN           NaN     NaN           NaN
# 997    998.0      A  New York        Member  Female       Shampoo
# 998      NaN    NaN       NaN           NaN     NaN           NaN
# 999   1000.0      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 0      Personal Care        5.50       3.0  1.16        17.66            1.0
# ...

# %% [markdown]
# ## _Data Exploration (Initial Analysis)_

# %%
df.head()
# Out:
#    sale_id branch      city customer_type  gender product_name  \
# 0      1.0      A  New York        Member    Male      Shampoo
# 1      NaN    NaN       NaN           NaN     NaN          NaN
# 2      3.0      A  New York        Member  Female        Apple
# 3      4.0      A   Chicago        Normal    Male    Detergent
# 4      NaN    NaN       NaN           NaN     NaN          NaN
#
#   product_category  unit_price  quantity   tax  total_price  reward_points
# 0    Personal Care         5.5       3.0  1.16        17.66            1.0
# 1              NaN         NaN       NaN   NaN          NaN            NaN
# 2           Fruits         1.2      15.0  1.26        19.26            1.0
# 3        Household         7.8       5.0  2.73        41.73            0.0
# 4              NaN         NaN       NaN   NaN          NaN            NaN

# %%
df.tail()
# Out:
#      sale_id branch      city customer_type  gender  product_name  \
# 995      NaN    NaN       NaN           NaN     NaN           NaN
# 996      NaN    NaN       NaN           NaN     NaN           NaN
# 997    998.0      A  New York        Member  Female       Shampoo
# 998      NaN    NaN       NaN           NaN     NaN           NaN
# 999   1000.0      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 995              NaN         NaN       NaN   NaN          NaN            NaN
# 996              NaN         NaN       NaN   NaN          NaN            NaN
# 997       Stationery       17.92       2.0  2.51        38.35            3.0
# 998              NaN         NaN       NaN   NaN          NaN            NaN
# 999       Stationery        4.11       4.0  1.15        17.59            0.0

# %%
df.sample()
# Out:
#      sale_id branch         city customer_type  gender  product_name  \
# 433    434.0      B  Los Angeles        Normal  Female  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 433        Household       13.78       5.0  4.82        73.72            0.0

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.size
# Out:
# 12000

# %%
df[["sale_id","gender"]]
df
# Out:
#      sale_id branch      city customer_type  gender  product_name  \
# 0        1.0      A  New York        Member    Male       Shampoo
# 1        NaN    NaN       NaN           NaN     NaN           NaN
# 2        3.0      A  New York        Member  Female         Apple
# 3        4.0      A   Chicago        Normal    Male     Detergent
# 4        NaN    NaN       NaN           NaN     NaN           NaN
# ..       ...    ...       ...           ...     ...           ...
# 995      NaN    NaN       NaN           NaN     NaN           NaN
# 996      NaN    NaN       NaN           NaN     NaN           NaN
# 997    998.0      A  New York        Member  Female       Shampoo
# 998      NaN    NaN       NaN           NaN     NaN           NaN
# 999   1000.0      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 0      Personal Care        5.50       3.0  1.16        17.66            1.0
# ...

# %%
df.product_name
# Out:
# 0           Shampoo
# 1               NaN
# 2             Apple
# 3         Detergent
# 4               NaN
#            ...
# 995             NaN
# 996             NaN
# 997         Shampoo
# 998             NaN
# 999    Orange Juice
# Name: product_name, Length: 1000, dtype: object

# %%
df.dtypes
# Out:
# sale_id             float64
# branch               object
# city                 object
# customer_type        object
# gender               object
# product_name         object
# product_category     object
# unit_price          float64
# quantity            float64
# tax                 float64
# total_price         float64
# reward_points       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sale_id           448 non-null    float64
#  1   branch            448 non-null    object
#  2   city              448 non-null    object
#  3   customer_type     448 non-null    object
#  4   gender            448 non-null    object
#  5   product_name      448 non-null    object
#  6   product_category  448 non-null    object
#  7   unit_price        448 non-null    float64
#  8   quantity          448 non-null    float64
#  9   tax               448 non-null    float64
#  10  total_price       448 non-null    float64
#  11  reward_points     448 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#            sale_id  unit_price    quantity         tax  total_price  \
# count   448.000000  448.000000  448.000000  448.000000   448.000000
# mean    490.926339   10.819263   10.388393    7.676496   117.338817
# std     286.386508    5.861654    5.994483    6.388490    97.649963
# min       1.000000    1.070000    1.000000    0.180000     2.700000
# 25%     250.750000    5.867500    5.000000    2.537500    38.747500
# 50%     489.000000   10.465000   10.000000    5.975000    91.275000
# 75%     733.250000   16.000000   16.000000   11.397500   174.185000
# max    1000.000000   20.960000   20.000000   27.680000   423.080000
#
#        reward_points
# count     448.000000
# mean        6.149554
# std         9.169176
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%        10.250000
# max        41.000000

# %%
df.describe(include='all')
# Out:
#             sale_id branch     city customer_type  gender product_name  \
# count    448.000000    448      448           448     448          448
# unique          NaN      2        3             2       2            5
# top             NaN      A  Chicago        Member  Female      Shampoo
# freq            NaN    298      158           237     228          100
# mean     490.926339    NaN      NaN           NaN     NaN          NaN
# std      286.386508    NaN      NaN           NaN     NaN          NaN
# min        1.000000    NaN      NaN           NaN     NaN          NaN
# 25%      250.750000    NaN      NaN           NaN     NaN          NaN
# 50%      489.000000    NaN      NaN           NaN     NaN          NaN
# 75%      733.250000    NaN      NaN           NaN     NaN          NaN
# max     1000.000000    NaN      NaN           NaN     NaN          NaN
#
#        product_category  unit_price    quantity         tax  total_price  \
# ...

# %% [markdown]
# ## _Data Cleaning_

# %%
df.rename(columns={'sale_id':'ID'},inplace=True)
df.sample()
# Out:
#      ID branch city customer_type gender product_name product_category  \
# 472 NaN    NaN  NaN           NaN    NaN          NaN              NaN
#
#      unit_price  quantity  tax  total_price  reward_points
# 472         NaN       NaN  NaN          NaN            NaN

# %%
df.dropna()
# Out:
#          ID branch      city customer_type  gender  product_name  \
# 0       1.0      A  New York        Member    Male       Shampoo
# 2       3.0      A  New York        Member  Female         Apple
# 3       4.0      A   Chicago        Normal    Male     Detergent
# 5       6.0      A   Chicago        Normal    Male       Shampoo
# 6       7.0      A   Chicago        Normal    Male       Shampoo
# ..      ...    ...       ...           ...     ...           ...
# 990   991.0      A   Chicago        Normal  Female     Detergent
# 993   994.0      A  New York        Normal  Female  Orange Juice
# 994   995.0      A  New York        Member    Male      Notebook
# 997   998.0      A  New York        Member  Female       Shampoo
# 999  1000.0      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 0      Personal Care        5.50       3.0  1.16        17.66            1.0
# ...

# %%
df.fillna(786)
# Out:
#          ID branch      city customer_type  gender  product_name  \
# 0       1.0      A  New York        Member    Male       Shampoo
# 1     786.0    786       786           786     786           786
# 2       3.0      A  New York        Member  Female         Apple
# 3       4.0      A   Chicago        Normal    Male     Detergent
# 4     786.0    786       786           786     786           786
# ..      ...    ...       ...           ...     ...           ...
# 995   786.0    786       786           786     786           786
# 996   786.0    786       786           786     786           786
# 997   998.0      A  New York        Member  Female       Shampoo
# 998   786.0    786       786           786     786           786
# 999  1000.0      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity     tax  total_price  reward_points
# 0      Personal Care        5.50       3.0    1.16        17.66            1.0
# ...

# %%
df=df.drop(columns=["gender"])
df
# Out:
#          ID branch      city customer_type  product_name product_category  \
# 0       1.0      A  New York        Member       Shampoo    Personal Care
# 1       NaN    NaN       NaN           NaN           NaN              NaN
# 2       3.0      A  New York        Member         Apple           Fruits
# 3       4.0      A   Chicago        Normal     Detergent        Household
# 4       NaN    NaN       NaN           NaN           NaN              NaN
# ..      ...    ...       ...           ...           ...              ...
# 995     NaN    NaN       NaN           NaN           NaN              NaN
# 996     NaN    NaN       NaN           NaN           NaN              NaN
# 997   998.0      A  New York        Member       Shampoo       Stationery
# 998     NaN    NaN       NaN           NaN           NaN              NaN
# 999  1000.0      A  New York        Normal  Orange Juice       Stationery
#
#      unit_price  quantity   tax  total_price  reward_points
# ...

# %%
# To drop columns
del df["product_name"]
df
# Out:
#          ID branch      city customer_type product_category  unit_price  \
# 0       1.0      A  New York        Member    Personal Care        5.50
# 1       NaN    NaN       NaN           NaN              NaN         NaN
# 2       3.0      A  New York        Member           Fruits        1.20
# 3       4.0      A   Chicago        Normal        Household        7.80
# 4       NaN    NaN       NaN           NaN              NaN         NaN
# ..      ...    ...       ...           ...              ...         ...
# 995     NaN    NaN       NaN           NaN              NaN         NaN
# 996     NaN    NaN       NaN           NaN              NaN         NaN
# 997   998.0      A  New York        Member       Stationery       17.92
# 998     NaN    NaN       NaN           NaN              NaN         NaN
# 999  1000.0      A  New York        Normal       Stationery        4.11
#
#      quantity   tax  total_price  reward_points
# 0         3.0  1.16        17.66            1.0
# ...

# %%
# To drop rows
df = df.drop(4)
df
# Out:
#          ID branch      city customer_type product_category  unit_price  \
# 0       1.0      A  New York        Member    Personal Care        5.50
# 1       NaN    NaN       NaN           NaN              NaN         NaN
# 2       3.0      A  New York        Member           Fruits        1.20
# 3       4.0      A   Chicago        Normal        Household        7.80
# 5       6.0      A   Chicago        Normal       Stationery       11.24
# ..      ...    ...       ...           ...              ...         ...
# 995     NaN    NaN       NaN           NaN              NaN         NaN
# 996     NaN    NaN       NaN           NaN              NaN         NaN
# 997   998.0      A  New York        Member       Stationery       17.92
# 998     NaN    NaN       NaN           NaN              NaN         NaN
# 999  1000.0      A  New York        Normal       Stationery        4.11
#
#      quantity   tax  total_price  reward_points
# 0         3.0  1.16        17.66            1.0
# ...

# %%
df.isnull()
# Out:
#         ID  branch   city  customer_type  product_category  unit_price  \
# 0    False   False  False          False             False       False
# 1     True    True   True           True              True        True
# 2    False   False  False          False             False       False
# 3    False   False  False          False             False       False
# 5    False   False  False          False             False       False
# ..     ...     ...    ...            ...               ...         ...
# 995   True    True   True           True              True        True
# 996   True    True   True           True              True        True
# 997  False   False  False          False             False       False
# 998   True    True   True           True              True        True
# 999  False   False  False          False             False       False
#
#      quantity    tax  total_price  reward_points
# 0       False  False        False          False
# ...

# %%
df.isnull().sum()
# Out:
# ID                  551
# branch              551
# city                551
# customer_type       551
# product_category    551
# unit_price          551
# quantity            551
# tax                 551
# total_price         551
# reward_points       551
# dtype: int64

# %% [markdown]
# ## _Data Manipulation_

# %%
df.insert(5, "centuries", 5)
df
# Out:
#          ID branch      city customer_type product_category  centuries  \
# 0       1.0      A  New York        Member    Personal Care          5
# 1       NaN    NaN       NaN           NaN              NaN          5
# 2       3.0      A  New York        Member           Fruits          5
# 3       4.0      A   Chicago        Normal        Household          5
# 5       6.0      A   Chicago        Normal       Stationery          5
# ..      ...    ...       ...           ...              ...        ...
# 995     NaN    NaN       NaN           NaN              NaN          5
# 996     NaN    NaN       NaN           NaN              NaN          5
# 997   998.0      A  New York        Member       Stationery          5
# 998     NaN    NaN       NaN           NaN              NaN          5
# 999  1000.0      A  New York        Normal       Stationery          5
#
#      unit_price  quantity   tax  total_price  reward_points
# ...

# %%
df['tax.mean']=df["tax"].mean()
df['tax.mean']
df
# Out:
#          ID branch      city customer_type product_category  centuries  \
# 0       1.0      A  New York        Member    Personal Care          5
# 1       NaN    NaN       NaN           NaN              NaN          5
# 2       3.0      A  New York        Member           Fruits          5
# 3       4.0      A   Chicago        Normal        Household          5
# 5       6.0      A   Chicago        Normal       Stationery          5
# ..      ...    ...       ...           ...              ...        ...
# 995     NaN    NaN       NaN           NaN              NaN          5
# 996     NaN    NaN       NaN           NaN              NaN          5
# 997   998.0      A  New York        Member       Stationery          5
# 998     NaN    NaN       NaN           NaN              NaN          5
# 999  1000.0      A  New York        Normal       Stationery          5
#
#      unit_price  quantity   tax  total_price  reward_points  tax.mean
# ...

# %%
df['total_price'].fillna(('max'),inplace=True)
df['total_price']
# Out:
# C:\Users\MG\AppData\Local\Temp\ipykernel_12948\971115005.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['total_price'].fillna(('max'),inplace=True)
# C:\Users\MG\AppData\Local\Temp\ipykernel_12948\971115005.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['total_price'].fillna(('max'),inplace=True)
# 0       17.66
# ...

# %%
df['new_column']=df["unit_price"]+df['total_price']
df
# Out:
#          ID branch      city customer_type product_category  centuries  \
# 0       1.0      A  New York        Member    Personal Care          5
# 1       NaN    NaN       NaN           NaN              NaN          5
# 2       3.0      A  New York        Member           Fruits          5
# 3       4.0      A   Chicago        Normal        Household          5
# 5       6.0      A   Chicago        Normal       Stationery          5
# ..      ...    ...       ...           ...              ...        ...
# 995     NaN    NaN       NaN           NaN              NaN          5
# 996     NaN    NaN       NaN           NaN              NaN          5
# 997   998.0      A  New York        Member       Stationery          5
# 998     NaN    NaN       NaN           NaN              NaN          5
# 999  1000.0      A  New York        Normal       Stationery          5
#
#      unit_price  quantity   tax total_price  reward_points  tax.mean  \
# ...

# %% [markdown]
# ## _Data Selection_

# %%
# To add rows
df.loc[4]=[4.00, "A","New York", "Member","Vegetables", 5, 1.52, 6.0, 6.08, 456, 0.0, 7.66499 ,76.9]
df

# %%
df.loc[5]
# Out:
# sale_id                    6.0
# branch                       A
# city                   Chicago
# customer_type           Normal
# product_category    Stationery
# centuries                    5
# unit_price               11.24
# quantity                   9.0
# tax                       7.08
# total_price             108.24
# reward_points              0.0
# tax.mean              7.676496
# new_column              119.48
# Name: 5, dtype: object

# %%
df.loc[567, ["unit_price", "total_price"]]
# Out:
# unit_price      15.0
# total_price    192.6
# Name: 567, dtype: object

# %%
df.iloc[3,8]
# Out:
# np.float64(2.73)

# %%
df.iloc[[3,4]]
# Out:
#    sale_id branch     city customer_type product_category  centuries  \
# 3      4.0      A  Chicago        Normal        Household          5
# 5      6.0      A  Chicago        Normal       Stationery          5
#
#    unit_price  quantity   tax total_price  reward_points  tax.mean new_column
# 3        7.80       5.0  2.73       41.73            0.0  7.676496      49.53
# 5       11.24       9.0  7.08      108.24            0.0  7.676496     119.48

# %%
df.iloc[[3,4],7]
# Out:
# 3    5.0
# 5    9.0
# Name: quantity, dtype: float64

# %% [markdown]
# ## _Statistical Analysis_

# %%
df['tax'].mean()
# Out:
# np.float64(7.67293986636971)

# %%
df['tax'].median()
# Out:
# np.float64(6.01)

# %%
df['tax'].mode()
# Out:
# 0     0.47
# 1     1.09
# 2     1.23
# 3     1.30
# 4     1.44
# 5     2.72
# 6    10.46
# Name: tax, dtype: float64

# %%
df['tax'].min()
# Out:
# np.float64(0.18)

# %%
df['tax'].max()
# Out:
# np.float64(27.68)

# %%
df['tax'].std()
# Out:
# np.float64(6.381801014998555)

# %% [markdown]
# ## _Handle Duplicates_

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      sale_id branch      city customer_type product_category  centuries  \
# 0        1.0      A  New York        Member    Personal Care          5
# 1        NaN    NaN       NaN           NaN              NaN          5
# 2        3.0      A  New York        Member           Fruits          5
# 3        4.0      A   Chicago        Normal        Household          5
# 5        6.0      A   Chicago        Normal       Stationery          5
# ..       ...    ...       ...           ...              ...        ...
# 996      NaN    NaN       NaN           NaN              NaN          5
# 997    998.0      A  New York        Member       Stationery          5
# 998      NaN    NaN       NaN           NaN              NaN          5
# 999   1000.0      A  New York        Normal       Stationery          5
# 4        4.0      A  New York        Member      Vegetablles          5
#
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      sale_id branch      city customer_type product_category  centuries  \
# 0        1.0      A  New York        Member    Personal Care          5
# 1        NaN    NaN       NaN           NaN              NaN          5
# 2        3.0      A  New York        Member           Fruits          5
# 3        4.0      A   Chicago        Normal        Household          5
# 5        6.0      A   Chicago        Normal       Stationery          5
# ..       ...    ...       ...           ...              ...        ...
# 996      NaN    NaN       NaN           NaN              NaN          5
# 997    998.0      A  New York        Member       Stationery          5
# 998      NaN    NaN       NaN           NaN              NaN          5
# 999   1000.0      A  New York        Normal       Stationery          5
# 4        4.0      A  New York        Member      Vegetablles          5
#
# ...

# %%
df["centuries"] = df["centuries"].replace(5, 7)
df
# Out:
#      sale_id branch      city customer_type product_category  centuries  \
# 0        1.0      A  New York        Member    Personal Care          7
# 1        NaN    NaN       NaN           NaN              NaN          7
# 2        3.0      A  New York        Member           Fruits          7
# 3        4.0      A   Chicago        Normal        Household          7
# 5        6.0      A   Chicago        Normal       Stationery          7
# ..       ...    ...       ...           ...              ...        ...
# 996      NaN    NaN       NaN           NaN              NaN          7
# 997    998.0      A  New York        Member       Stationery          7
# 998      NaN    NaN       NaN           NaN              NaN          7
# 999   1000.0      A  New York        Normal       Stationery          7
# 4        4.0      A  New York        Member      Vegetablles          7
#
#      unit_price  quantity   tax total_price  reward_points  tax.mean  \
# ...

# %% [markdown]
# ## _Change Data Type_

# %%
df["centuries"] = df["centuries"].astype(bool)
df.dtypes
# Out:
# sale_id             float64
# branch               object
# city                 object
# customer_type        object
# product_category     object
# centuries              bool
# unit_price          float64
# quantity            float64
# tax                 float64
# total_price          object
# reward_points       float64
# tax.mean            float64
# new_column           object
# dtype: object

# %% [markdown]
# ## _Analyzing Data_

# %%
df.groupby("unit_price").describe()
df
# Out:
#      sale_id branch      city customer_type product_category  centuries  \
# 0        1.0      A  New York        Member    Personal Care       True
# 1        NaN    NaN       NaN           NaN              NaN       True
# 2        3.0      A  New York        Member           Fruits       True
# 3        4.0      A   Chicago        Normal        Household       True
# 5        6.0      A   Chicago        Normal       Stationery       True
# ..       ...    ...       ...           ...              ...        ...
# 996      NaN    NaN       NaN           NaN              NaN       True
# 997    998.0      A  New York        Member       Stationery       True
# 998      NaN    NaN       NaN           NaN              NaN       True
# 999   1000.0      A  New York        Normal       Stationery       True
# 4        4.0      A  New York        Member      Vegetablles       True
#
#      unit_price  quantity   tax total_price  reward_points  tax.mean  \
# ...

# %%
df.groupby('centuries')['tax'].sum()
# Out:
# centuries
# True    3445.15
# Name: tax, dtype: float64

# %%
df.sort_values(by='tax', ascending=False)
# Out:
#      sale_id branch         city customer_type product_category  centuries  \
# 621    622.0      A     New York        Normal           Fruits       True
# 56      57.0      A      Chicago        Member        Beverages       True
# 260    261.0      B  Los Angeles        Member        Beverages       True
# 331    332.0      A     New York        Member    Personal Care       True
# 811    812.0      B  Los Angeles        Normal        Beverages       True
# ..       ...    ...          ...           ...              ...        ...
# 991      NaN    NaN          NaN           NaN              NaN       True
# 992      NaN    NaN          NaN           NaN              NaN       True
# 995      NaN    NaN          NaN           NaN              NaN       True
# 996      NaN    NaN          NaN           NaN              NaN       True
# 998      NaN    NaN          NaN           NaN              NaN       True
#
# ...

# %%
df.filter(like='unit_price', axis=1)
# Out:
#      unit_price
# 0          5.50
# 1           NaN
# 2          1.20
# 3          7.80
# 5         11.24
# ..          ...
# 996         NaN
# 997       17.92
# 998         NaN
# 999        4.11
# 4          1.52
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## _Visualization_

# %%
df["unit_price"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='unit_price'>

# %%
df["unit_price"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='unit_price'>

# %%
df["unit_price"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='unit_price'>

# %%
df["unit_price"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df["unit_price"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["unit_price"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["unit_price"].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["total_price"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='total_price'>

# %%
df["total_price"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## _Final Export_

# %%
df = pd.read_csv("sales_with_nulls.csv")
df
df.to_excel("new_project.xlsx", sheet_name="secsheet")
